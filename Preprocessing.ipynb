# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler,Binarizer,Normalizer,OneHotEncoder,LabelEncoder

# %%
np.random.seed(10)

# %%
a=np.random.normal(0,1,500)
b=np.random.normal(-2,2,500)
c=np.random.normal(5,3,500)

# %%
df = pd.DataFrame({
    'A' : a,
    'B' : b,
    'C' : c
})
df
# Out:
#             A         B         C
# 0    1.331587  0.878507  9.539757
# 1    0.715279  0.764293  4.572999
# 2   -1.545400 -0.157359  4.581740
# 3   -0.008384 -3.145774  8.526523
# 4    0.621336  0.550098  8.551367
# ..        ...       ...       ...
# 495  0.487696 -4.028678  7.408553
# 496  0.056315 -2.663655  4.095107
# 497  0.545784  0.881395  3.326296
# 498 -0.683122 -2.780436  1.309574
# 499 -0.659017 -0.715099  3.905265
#
# [500 rows x 3 columns]

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
scalar=StandardScaler()
scaled=scalar.fit_transform(df)
df=pd.DataFrame(scaled,columns=['a','b','c'])

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
mmm=MinMaxScaler()

# %%
mm=mmm.fit_transform(df)
df=pd.DataFrame(mm,columns=['c','u','t'])

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
dat= pd.read_csv("C:/Users/samru/Downloads/ZyQwcPipm0/session 3/DATASETS/encoding.csv")

# %%
dat
# Out:
#   TEAM  YEAR
# 0    A  2000
# 1    B  2002
# 2    C  2003
# 3    D  2004
# 4    A  2005
# 5    C  2006
# 6    B  2007
# 7    A  2008
# 8    D  2009

# %%
le=LabelEncoder()

# %%
dat.TEAM=le.fit_transform(dat.TEAM)

# %%
dat
# Out:
#    TEAM  YEAR
# 0     0  2000
# 1     1  2002
# 2     2  2003
# 3     3  2004
# 4     0  2005
# 5     2  2006
# 6     1  2007
# 7     0  2008
# 8     3  2009
